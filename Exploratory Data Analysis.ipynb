# %% [markdown]
# <a href="https://colab.research.google.com/github/kwabena55/Machine-Learning-Pipelines/blob/master/Exploratory%20Data%20Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Building Machine Learning Pipelines: Data Analysis Phase
# In this and the upcoming videos we will focus on creating Machine Learning Pipelines considering all the life cycle of a Data Science Projects. This will be important for professionals who have not worked with huge dataset.
#
# # Project Name: House Prices: Advanced Regression Techniques
# The main aim of this project is to predict the house price based on various features which we will discuss as we go ahead
#
# ## Dataset to downloaded from the below link
# https://www.kaggle.com/c/house-prices-advanced-regression-techniques/data
#
# # All the Lifecycle In A Data Science Projects
# - Data Analysis
# - Feature Engineering
# - Feature Selection
# - Model Building
# - Model Deployment

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# Display all Column in DataFrame
pd.pandas.set_option('display.max_columns', None)

# %%
ls
# Out:
# sample_data/

# %%
#Import Data In Google Colab
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /gdrive
# /gdrive

# %%
# %ls
# %cd 'My Drive'
# %ls
# Out:
# 'A complete Guide to TensorFlow 2.0- Hadelin'/
# 'Analytics in Hadoop.docx'
# 'Apache Spark'/
# 'AWS CERTIFIED DEVELOPER'/
# 'AWS SAGEMAKER'/
#  Certificates/
# 'Chrome Passwords.csv'
#  Cloudticians/
# 'Colab Notebooks'/
#  ColdSteele_python/
# 'Contact Information.gform'
# 'Copy of scan0003.pdf'
# 'Data analysis with Pandas'/
# 'Data Science books'/
# 'Deploy ML Models'/
#  documents/
#  edx/
# 'Fwd: BUAH RUTH 01MAR2020 ACC LHR (1).pdf'
# 'Fwd: BUAH RUTH 01MAR2020 ACC LHR.pdf'
#  Geocoding/
# 'Git and GitHub'/
#  kobold/
# 'ML Classification Bootcamp'/
# 'ML Regression Master Class'/
#  My-Data-Science-Projects-master/
# 'Other codes from Internet'/
# 'Pandas Data School'/
# 'PowerBI Training'/
# 'PR application'/
# 'Python and Spark for Big Data'/
# 'Python books'/
#  Refactored_Py_DS_ML_Bootcamp-master/
#  Resume/
# 'Scraping books'/
#  scripts/
# 'SDS Machine Learning A-Z'/
#  Snowflake/
# 'SnowFlake Documentation'/
#  SQL/
# 'TensorFlow 2.0'/
# 'Time Series Analysis'/
# ...

# %%
# %cd Data
# Out:
# /gdrive/My Drive/Data

# %%
data=pd.read_csv('train.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
data.shape
# Out:
# (1460, 81)

# %%
data.head(3)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5       2003
# 1       Norm     1Fam     1Story            6            8       1976
# 2       Norm     1Fam     2Story            7            5       2001
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# ...

# %% [markdown]
# # In Data Analysis lets try to make insights on this
# - Missing Values
# - All the numerical variables
# - Distribution of Numerical Variables
# - Categorical Variables
# - Cardinality of Categorical variables
# - Outliers
# - Relationship between Independent and dependent feature (Sale Price)

# %% [markdown]
# # Missing Values

# %%
data.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
missing_features=[features for features in data.columns if data[features].isnull().sum() > 1 ]

print(missing_features)
# Out:
# ['LotFrontage', 'Alley', 'MasVnrType', 'MasVnrArea', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'FireplaceQu', 'GarageType', 'GarageYrBlt', 'GarageFinish', 'GarageQual', 'GarageCond', 'PoolQC', 'Fence', 'MiscFeature']

# %%
for feature in missing_features:
    print('The Perecentage of missing ' ,feature, ' is', np.round(((data[feature].isnull().sum())/len(data)) * 100,2), '%' )
# Out:
# The Perecentage of missing  LotFrontage  is 17.74 %
# The Perecentage of missing  Alley  is 93.77 %
# The Perecentage of missing  MasVnrType  is 0.55 %
# The Perecentage of missing  MasVnrArea  is 0.55 %
# The Perecentage of missing  BsmtQual  is 2.53 %
# The Perecentage of missing  BsmtCond  is 2.53 %
# The Perecentage of missing  BsmtExposure  is 2.6 %
# The Perecentage of missing  BsmtFinType1  is 2.53 %
# The Perecentage of missing  BsmtFinType2  is 2.6 %
# The Perecentage of missing  FireplaceQu  is 47.26 %
# The Perecentage of missing  GarageType  is 5.55 %
# The Perecentage of missing  GarageYrBlt  is 5.55 %
# The Perecentage of missing  GarageFinish  is 5.55 %
# The Perecentage of missing  GarageQual  is 5.55 %
# The Perecentage of missing  GarageCond  is 5.55 %
# The Perecentage of missing  PoolQC  is 99.52 %
# The Perecentage of missing  Fence  is 80.75 %
# The Perecentage of missing  MiscFeature  is 96.3 %

# %%
data[missing_features].shape
# Out:
# (1460, 18)

# %% [markdown]
# ### Sum of Sales Price for Missing Values against Sum of Sales Price for Non Missing Values for the Features
# - Check if there is a Depency or relationship

# %%
for feature in missing_features:
    data1=data.copy()
    
    
    data1[feature]=np.where(data1[feature].isnull(),1,0)
    data1.groupby(feature)['SalePrice'].median().plot.bar()
    plt.title(feature)
    plt.show()

# %% [markdown]
# From the Observation above it shows that there is somewhat relationship between a missing value sales price and non missing value  sale price so
# we cannot discard that stattisitc.

# %%
data1.shape
# Out:
# (1460, 81)

# %%
data1.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
# dropping the first obvious redundant column
data=data.drop( columns='Id')

# %%
data.shape
# Out:
# (1460, 80)

# %%
numerical_feature= [numeric for numeric in data.columns if data[numeric].dtypes != 'O']

# %%
len(numerical_feature)
# Out:
# 37

# %%
data[numerical_feature].head()
# Out:
#    MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0          60         65.0     8450            7            5       2003
# 1          20         80.0     9600            6            8       1976
# 2          60         68.0    11250            7            5       2001
# 3          70         60.0     9550            7            5       1915
# 4          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          2003       196.0         706           0        150          856
# 1          1976         0.0         978           0        284         1262
# 2          2002       162.0         486           0        434          920
# 3          1970         0.0         216           0        540          756
# 4          2000       350.0         655           0        490         1145
#
# ...

# %%
#plotting a histyogram of numerical features
for  i  in numerical_feature:
    data2=data.copy()
    plt.barh(i,len(i))
    plt.show()

# %% [markdown]
# # Temporal Variables
# - let categorize all year column into one which will help with the feature engineering process

# %%
TV= [ tv for tv in data.columns if 'Yr' in tv or 'Year' in tv]

# %%
TV
# Out:
# ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold']

# %%
TV_dframe= data[TV]

# %%
TV_dframe.head()
# Out:
#    YearBuilt  YearRemodAdd  GarageYrBlt  YrSold
# 0       2003          2003       2003.0    2008
# 1       1976          1976       1976.0    2007
# 2       2001          2002       2001.0    2008
# 3       1915          1970       1998.0    2006
# 4       2000          2000       2000.0    2008

# %% [markdown]
# # Show the disitnct values , count of distinct values  in each temporal variable

# %%
for values in TV:
#     z=data[values]
    x=data[values].unique()
    y=data[values].nunique()
    
    print(f" for {values}  the distinct values are : {x}   \n  and  the count is  {y}  \n  \n "    )
# Out:
#  for YearBuilt  the distinct values are : [2003 1976 2001 1915 2000 1993 2004 1973 1931 1939 1965 2005 1962 2006
#  1960 1929 1970 1967 1958 1930 2002 1968 2007 1951 1957 1927 1920 1966
#  1959 1994 1954 1953 1955 1983 1975 1997 1934 1963 1981 1964 1999 1972
#  1921 1945 1982 1998 1956 1948 1910 1995 1991 2009 1950 1961 1977 1985
#  1979 1885 1919 1990 1969 1935 1988 1971 1952 1936 1923 1924 1984 1926
#  1940 1941 1987 1986 2008 1908 1892 1916 1932 1918 1912 1947 1925 1900
#  1980 1989 1992 1949 1880 1928 1978 1922 1996 2010 1946 1913 1937 1942
#  1938 1974 1893 1914 1906 1890 1898 1904 1882 1875 1911 1917 1872 1905]
#   and  the count is  112
#
#
#  for YearRemodAdd  the distinct values are : [2003 1976 2002 1970 2000 1995 2005 1973 1950 1965 2006 1962 2007 1960
#  2001 1967 2004 2008 1997 1959 1990 1955 1983 1980 1966 1963 1987 1964
#  1972 1996 1998 1989 1953 1956 1968 1981 1992 2009 1982 1961 1993 1999
#  1985 1979 1977 1969 1958 1991 1971 1952 1975 2010 1984 1986 1994 1988
# ...

# %%
#Check if there is relationship  between the year the house was sold  and the Sales Price

data.groupby('YrSold')['SalePrice'].agg(['median','mean','max','min','count']).plot()

# %%
data.groupby('YrSold')['SalePrice'].agg(['median']).plot()

# %%
#Compare others years apart from yearSold to Saleprice
for year in TV_dframe.columns:
    if year != 'YrSold':
        data3=data.copy()
        x_col=data3[year]
        y=data3['SalePrice']
        plt.scatter(x_col,y)
        plt.xlabel(year)
        plt.ylabel('SalePrice')
        plt.title( year)
        plt.show()

# %% [markdown]
# # Discrete and Continous Variables
# - Discrete data involves round, concrete numbers that are determined by counting.
# - Continuous data involves complex numbers that are measured across a specific time interval.
#
# Basically, you can use the unique function to get the unique value and latwer you jusat found the count
# Or you can even use the nunique() function.

# %%
Discrete_feature = [ DF for DF in numerical_feature if len(data[DF].unique()) < 25 and DF not in TV]

# %%
Discrete_feature2 = [ DF for DF in numerical_feature if data[DF].nunique() < 25]
print ( f" The count of  Discrete Variable is {len(Discrete_feature2)}")
# Out:
#  The count of  Discrete Variable is 18

# %%
Discrete_feature2
# Out:
# ['MSSubClass',
#  'OverallQual',
#  'OverallCond',
#  'LowQualFinSF',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageCars',
#  '3SsnPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold',
#  'YrSold']

# %%
data[Discrete_feature].head()
# Out:
#    MSSubClass  OverallQual  OverallCond  LowQualFinSF  BsmtFullBath  \
# 0          60            7            5             0             1
# 1          20            6            8             0             0
# 2          60            7            5             0             1
# 3          70            7            5             0             1
# 4          60            8            5             0             1
#
#    BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd  \
# 0             0         2         1             3             1             8
# 1             1         2         0             3             1             6
# 2             0         2         1             3             1             6
# 3             0         1         0             3             1             7
# 4             0         2         1             4             1             9
#
#    Fireplaces  GarageCars  3SsnPorch  PoolArea  MiscVal  MoSold
# ...

# %%
# Always comapre your variables to your Feature in EDA
# Compare DV to Sales Price

for i in Discrete_feature:
    data.groupby(i)["SalePrice"].median().plot.bar(legend='best')
    plt.xlabel(i)
    plt.ylabel("SalePrice")
    plt.title(i)
    
    plt.show()

# %% [markdown]
# Looks like OverallQual has a monotonic relationship with SalePrice

# %% [markdown]
# # Continous Variable

# %%
Continous_feature = [ CF for CF in numerical_feature if CF not in Discrete_feature+TV]
print ( f" The count of  Continous Variable is {len(Continous_feature)}")
# Out:
#  The count of  Continous Variable is 16

# %%
Continous_feature
# Out:
# ['LotFrontage',
#  'LotArea',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'GrLivArea',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  'ScreenPorch',
#  'SalePrice']

# %%
# Always comapre your variables to your Feature in EDA
# Compare DV to Sales Price

for cv in Continous_feature:
    data[cv].hist(bins=25)
    plt.xlabel(cv)
    plt.ylabel("Count")
    plt.title(cv)
    plt.show()

# %% [markdown]
# # Logarithmic transformation for SalePrice

# %%
data.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave   NaN      Reg
# 1          20       RL         80.0     9600   Pave   NaN      Reg
# 2          60       RL         68.0    11250   Pave   NaN      IR1
# 3          70       RL         60.0     9550   Pave   NaN      IR1
# 4          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5       2003
# ...

# %%
data[Continous_feature].head()
# Out:
#    LotFrontage  LotArea  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# 0         65.0     8450       196.0         706           0        150
# 1         80.0     9600         0.0         978           0        284
# 2         68.0    11250       162.0         486           0        434
# 3         60.0     9550         0.0         216           0        540
# 4         84.0    14260       350.0         655           0        490
#
#    TotalBsmtSF  1stFlrSF  2ndFlrSF  GrLivArea  GarageArea  WoodDeckSF  \
# 0          856       856       854       1710         548           0
# 1         1262      1262         0       1262         460         298
# 2          920       920       866       1786         608           0
# 3          756       961       756       1717         642           0
# 4         1145      1145      1053       2198         836         192
#
#    OpenPorchSF  EnclosedPorch  ScreenPorch  SalePrice
# 0           61              0            0     208500
# ...

# %%
# datalog[Continous_feature]= data[Continous_feature].apply(np.log)

# %%
# datalog.head()

# %%
#So its evident when you find the log of zero you get -inf
#We dont want this in our code so lets take it out

for feature in Continous_feature:
    if 0 in data[feature].unique():
        pass
    else:
        data[feature]=data[feature].apply(np.log)

# %%
data[Continous_feature].head()
# Out:
#    LotFrontage   LotArea  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# 0     4.174387  9.041922       196.0         706           0        150
# 1     4.382027  9.169518         0.0         978           0        284
# 2     4.219508  9.328123       162.0         486           0        434
# 3     4.094345  9.164296         0.0         216           0        540
# 4     4.430817  9.565214       350.0         655           0        490
#
#    TotalBsmtSF  1stFlrSF  2ndFlrSF  GrLivArea  GarageArea  WoodDeckSF  \
# 0          856  6.752270       854   7.444249         548           0
# 1         1262  7.140453         0   7.140453         460         298
# 2          920  6.824374       866   7.487734         608           0
# 3          756  6.867974       756   7.448334         642           0
# 4         1145  7.043160      1053   7.695303         836         192
#
#    OpenPorchSF  EnclosedPorch  ScreenPorch  SalePrice
# 0           61              0            0  12.247694
# ...

# %%
#Replotting Normalized data
for cv in Continous_feature:
    plt.scatter(data[cv],data["SalePrice"])
    plt.xlabel(cv)
    plt.ylabel("Count")
    plt.title(cv)
    plt.show()

# %% [markdown]
# # Removing Outliers in your data
#
#
# ![image.png](attachment:image.png)

# %%
for feature in Continous_feature:
    if 0 in data[feature].unique():
        pass
    else:
        sns.boxplot(x=data[feature])
        plt.show()

# %%
#Or by Using Pandas
for feature in Continous_feature:
    if 0 in data[feature].unique():
        pass
    else:
        data.boxplot(column=[feature])
        plt.show()

# %% [markdown]
# # Categorical Variables

# %%
categorical_features=[feature for feature in data.columns if data[feature].dtype=='O']

# %%
categorical_features
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']

# %%
data[categorical_features].nunique()
# Out:
# MSZoning          5
# Street            2
# Alley             2
# LotShape          4
# LandContour       4
# Utilities         2
# LotConfig         5
# LandSlope         3
# Neighborhood     25
# Condition1        9
# Condition2        8
# BldgType          5
# HouseStyle        8
# RoofStyle         6
# RoofMatl          8
# Exterior1st      15
# Exterior2nd      16
# MasVnrType        4
# ExterQual         4
# ExterCond         5
# Foundation        6
# BsmtQual          4
# BsmtCond          4
# BsmtExposure      4
# BsmtFinType1      6
# BsmtFinType2      6
# Heating           6
# HeatingQC         5
# CentralAir        2
# Electrical        5
# KitchenQual       4
# Functional        7
# FireplaceQu       5
# GarageType        6
# GarageFinish      3
# GarageQual        5
# GarageCond        5
# PavedDrive        3
# PoolQC            3
# Fence             4
# MiscFeature       4
# SaleType          9
# SaleCondition     6
# dtype: int64

# %%
#Plotting Categorical Features against SalePrice
for i in categorical_features:
    data.groupby(i)['SalePrice'].median().plot.bar()
    plt.xlabel(i)
    plt.ylabel('SalePrice')
    plt.title(i)
    plt.show()

# %%
data.head()
# Out:
#    MSSubClass MSZoning  LotFrontage   LotArea Street Alley LotShape  \
# 0          60       RL     4.174387  9.041922   Pave   NaN      Reg
# 1          20       RL     4.382027  9.169518   Pave   NaN      Reg
# 2          60       RL     4.219508  9.328123   Pave   NaN      IR1
# 3          70       RL     4.094345  9.164296   Pave   NaN      IR1
# 4          60       RL     4.430817  9.565214   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5       2003
# ...

# %% [markdown]
# # Feature Engineering

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(data, data["SalePrice"], test_size=0.2, random_state=True)

# %%
x_train.head()
# Out:
#       MSSubClass MSZoning  LotFrontage   LotArea Street Alley LotShape  \
# 921           90       RL     4.204693  9.079890   Pave   NaN      Reg
# 520          190       RL     4.094345  9.287301   Pave  Grvl      Reg
# 401           20       RL     4.174387  9.078750   Pave   NaN      IR1
# 280           60       RL     4.406719  9.331407   Pave   NaN      Reg
# 1401          60       RL     4.127134  8.911260   Pave   NaN      IR1
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 921          Lvl    AllPub    Inside       Gtl      Edwards      Feedr
# 520          Lvl    AllPub    Inside       Gtl      OldTown       Norm
# 401          Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 280          Lvl    AllPub    Inside       Gtl      SawyerW       Norm
# 1401         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
x_train.shape, x_test.shape
# Out:
# ((1168, 80), (292, 80))

# %% [markdown]
# # Replace  Categorical Missing Values

# %%
features_nan=[feature for feature in data.columns if data[feature].isnull().sum() >1 and data[feature].dtypes=='O']

for i in features_nan:
    print(i, np.round(((data[i].isnull().sum())/len(data))* 100,2), '%')
# Out:
# Alley 93.77 %
# MasVnrType 0.55 %
# BsmtQual 2.53 %
# BsmtCond 2.53 %
# BsmtExposure 2.6 %
# BsmtFinType1 2.53 %
# BsmtFinType2 2.6 %
# FireplaceQu 47.26 %
# GarageType 5.55 %
# GarageFinish 5.55 %
# GarageQual 5.55 %
# GarageCond 5.55 %
# PoolQC 99.52 %
# Fence 80.75 %
# MiscFeature 96.3 %

# %%
#Replace Missing Values with new label
for i in features_nan:
    data[i]=data[i].fillna('Missing')

# %%
data
# Out:
#       MSSubClass MSZoning  LotFrontage   LotArea Street    Alley LotShape  \
# 0             60       RL     4.174387  9.041922   Pave  Missing      Reg
# 1             20       RL     4.382027  9.169518   Pave  Missing      Reg
# 2             60       RL     4.219508  9.328123   Pave  Missing      IR1
# 3             70       RL     4.094345  9.164296   Pave  Missing      IR1
# 4             60       RL     4.430817  9.565214   Pave  Missing      IR1
# ...          ...      ...          ...       ...    ...      ...      ...
# 1455          60       RL     4.127134  8.976768   Pave  Missing      Reg
# 1456          20       RL     4.442651  9.486076   Pave  Missing      Reg
# 1457          70       RL     4.189655  9.109636   Pave  Missing      Reg
# 1458          20       RL     4.219508  9.181632   Pave  Missing      Reg
# 1459          20       RL     4.317488  9.204020   Pave  Missing      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# ...

# %%
#No missing Values for now

data[features_nan].isnull().sum()
# Out:
# Alley           0
# MasVnrType      0
# BsmtQual        0
# BsmtCond        0
# BsmtExposure    0
# BsmtFinType1    0
# BsmtFinType2    0
# FireplaceQu     0
# GarageType      0
# GarageFinish    0
# GarageQual      0
# GarageCond      0
# PoolQC          0
# Fence           0
# MiscFeature     0
# dtype: int64

# %% [markdown]
# # Replace Numerical Missing Values
# Replace Numerical Values with Median values

# %%
numerical_with_nan=[feature for feature in data.columns if data[feature].isnull().sum() >1 and data[feature].dtypes!='O']

for i in numerical_with_nan:
    print(i, np.round(((data[i].isnull().sum())/len(data))* 100,2), '%')
# Out:
# LotFrontage 17.74 %
# MasVnrArea 0.55 %
# GarageYrBlt 5.55 %

# %%
for i in numerical_with_nan:
    data[i]=data[i].fillna(data[i].median())

# %%
data[numerical_with_nan].isnull().sum()
# Out:
# LotFrontage    0
# MasVnrArea     0
# GarageYrBlt    0
# dtype: int64

# %%
# data[numerical_with_nan]

# %% [markdown]
# # Temporal Variables

# %%
for i in ['YearBuilt','YearRemodAdd','GarageYrBlt']:
    data[i]=data['YrSold']-data[i]

# %%
data[['YearBuilt','YearRemodAdd','GarageYrBlt']].head()
# Out:
#    YearBuilt  YearRemodAdd  GarageYrBlt
# 0          5             5          5.0
# 1         31            31         31.0
# 2          7             6          7.0
# 3         91            36          8.0
# 4          8             8          8.0

# %%
data.head()
# Out:
#    MSSubClass MSZoning  LotFrontage   LotArea Street    Alley LotShape  \
# 0          60       RL     4.174387  9.041922   Pave  Missing      Reg
# 1          20       RL     4.382027  9.169518   Pave  Missing      Reg
# 2          60       RL     4.219508  9.328123   Pave  Missing      IR1
# 3          70       RL     4.094345  9.164296   Pave  Missing      IR1
# 4          60       RL     4.430817  9.565214   Pave  Missing      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %% [markdown]
# # Replace Categorical values with less than 1% of total count with Rare_var

# %%
# for i in categorical_features:
#     temp=data.groupby(i)['SalePrice'].count()/len(data)
#     temp_df=temp[temp >0.01].index
#     data[i]=np.where(data[i].isin(temp_df),data[i],'Rare_var')

# %% [markdown]
# # Feature Scaling
# ### Information Leakage
#
# - Lots of ideas on Standardization  and Normalization
# - You can fit on the training data and you will use that that to transform the testing ( information leakage)
# - Or you can fot _transform them differently

# %%
feature_scale=[i for i in data.columns if data[i].dtype !='O' and i not in [ 'SalePrice']]
len(feature_scale)
# Out:
# 36

# %%
from sklearn.preprocessing import MinMaxScaler
MinMax=MinMaxScaler()

MinMax.fit_transform(data[feature_scale])
# Out:
# array([[0.23529412, 0.41820812, 0.3663439 , ..., 0.        , 0.09090909,
#         0.5       ],
#        [0.        , 0.49506375, 0.39131677, ..., 0.        , 0.36363636,
#         0.25      ],
#        [0.23529412, 0.434909  , 0.4223585 , ..., 0.        , 0.72727273,
#         0.5       ],
#        ...,
#        [0.29411765, 0.42385922, 0.37959669, ..., 0.16129032, 0.36363636,
#         1.        ],
#        [0.        , 0.434909  , 0.39368765, ..., 0.        , 0.27272727,
#         1.        ],
#        [0.        , 0.47117546, 0.39806941, ..., 0.        , 0.45454545,
#         0.5       ]])

# %%
data[feature_scale]=pd.DataFrame(MinMax.fit_transform(data[feature_scale]),columns=[feature_scale])

# %%
data[feature_scale]
# Out:
#       MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  YearBuilt  \
# 0       0.235294     0.418208  0.366344     0.666667        0.500   0.036765
# 1       0.000000     0.495064  0.391317     0.555556        0.875   0.227941
# 2       0.235294     0.434909  0.422359     0.666667        0.500   0.051471
# 3       0.294118     0.388581  0.390295     0.666667        0.500   0.669118
# 4       0.235294     0.513123  0.468761     0.777778        0.500   0.058824
# ...          ...          ...       ...          ...          ...        ...
# 1455    0.235294     0.400718  0.353592     0.555556        0.500   0.058824
# 1456    0.000000     0.517503  0.453273     0.555556        0.625   0.235294
# 1457    0.294118     0.423859  0.379597     0.666667        1.000   0.507353
# 1458    0.000000     0.434909  0.393688     0.444444        0.625   0.441176
# 1459    0.000000     0.471175  0.398069     0.444444        0.625   0.316176
#
# ...

# %%
# !pip install xgboost

# %% [markdown]
# # Feature Selection

# %% [markdown]
# Select best features

# %%
Y_train= pd.DataFrame(data["SalePrice"])

# %%
X_train=pd.DataFrame(data.drop(columns=["SalePrice"]))

# %%
type(Y_train)
# Out:
# pandas.core.frame.DataFrame

# %%
X_train.shape
# Out:
# (1460, 79)
